# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods: 2007–2012 and 2019–2024
filtered_data = unemployment_data[
    ((unemployment_data["observation_date"] >= "2007-01-01") & (unemployment_data["observation_date"] <= "2012-12-31")) |
    ((unemployment_data["observation_date"] >= "2019-01-01") & (unemployment_data["observation_date"] <= "2024-12-31"))
]

# Line Graph: Monthly Unemployment Rates Over Time
plt.figure(figsize=(12, 6))
plt.plot(filtered_data["observation_date"], filtered_data["UNRATE"], marker='o', linestyle='-', label="Monthly Unemployment Rate")

# Highlight recession periods
plt.axvspan("2008-01-01", "2009-06-01", color='red', alpha=0.2, label="2008 Financial Crisis")
plt.axvspan("2020-03-01", "2020-12-01", color='blue', alpha=0.2, label="COVID-19 Pandemic")

# Graph details
plt.title("U.S. Monthly Unemployment Rate (2007–2012 & 2019–2024)", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Unemployment Rate (%)", fontsize=12)
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods: 2007–2012 and 2019–2024
filtered_data = unemployment_data[
    ((unemployment_data["observation_date"] >= "2007-01-01") & (unemployment_data["observation_date"] <= "2012-12-31")) |
    ((unemployment_data["observation_date"] >= "2019-01-01") & (unemployment_data["observation_date"] <= "2024-12-31"))
]

# Safely add the 'year' column
filtered_data.loc[:, "year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Bar Chart: Yearly Average Unemployment Rates
plt.figure(figsize=(10, 6))
plt.bar(yearly_averages["year"], yearly_averages["UNRATE"], color="skyblue", edgecolor="black")

# Highlight the crisis periods
plt.axvspan(2008, 2012, color='red', alpha=0.2, label="2008 Financial Crisis")
plt.axvspan(2019, 2024, color='blue', alpha=0.2, label="COVID-19 Pandemic")

# Graph details
plt.title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Unemployment Rate (%)", fontsize=12)
plt.xticks(yearly_averages["year"], rotation=45)
plt.grid(axis='y', alpha=0.3)
plt.legend()
plt.tight_layout()

plt.show()
# Out:
# /var/folders/_c/wwh4ntjd79zgv89r7tdw_dwc0000gn/T/ipykernel_56717/814520135.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data.loc[:, "year"] = filtered_data["observation_date"].dt.year

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods: 2007–2012 and 2019–2024
filtered_data = unemployment_data[
    ((unemployment_data["observation_date"] >= "2007-01-01") & (unemployment_data["observation_date"] <= "2012-12-31")) |
    ((unemployment_data["observation_date"] >= "2019-01-01") & (unemployment_data["observation_date"] <= "2024-12-31"))
]

# Safely add the 'year' column
filtered_data.loc[:, "year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Bar Chart: Yearly Average Unemployment Rates
plt.figure(figsize=(10, 6))
plt.bar(yearly_averages["year"], yearly_averages["UNRATE"], color="skyblue", edgecolor="black")

# Highlight the crisis periods
plt.axvspan(2008, 2012, color='red', alpha=0.2, label="2008 Financial Crisis")
plt.axvspan(2019, 2024, color='blue', alpha=0.2, label="COVID-19 Pandemic")

# Graph details
plt.title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Unemployment Rate (%)", fontsize=12)
plt.xticks(yearly_averages["year"], rotation=45)
plt.grid(axis='y', alpha=0.3)
plt.legend()
plt.tight_layout()

plt.show()
# Out:
# /var/folders/_c/wwh4ntjd79zgv89r7tdw_dwc0000gn/T/ipykernel_56717/814520135.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data.loc[:, "year"] = filtered_data["observation_date"].dt.year

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    ((unemployment_data["observation_date"] >= "2007-01-01") & (unemployment_data["observation_date"] <= "2012-12-31")) |
# Out:
#   Cell In[10], line 12
#     ((unemployment_data["observation_date"] >= "2007-01-01") & (unemployment_data["observation_date"] <= "2012-12-31")) |
#                                                                                                                          ^
# SyntaxError: incomplete input

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    ((unemployment_data["observation_date"] >= "2007-01-01") & (unemployment_data["observation_date"] <= "2012-12-31")) |
    ((unemployment_data["observation_date"] >= "2019-01-01") & (unemployment_data["observation_date"] <= "2024-12-31"))
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Bar Chart: Yearly Average Unemployment Rates
plt.figure(figsize=(15, 10))
plt.bar(yearly_averages["year"], yearly_averages["UNRATE"], color="skyblue", edgecolor="black")

# Highlight the crisis periods
plt.axvspan(2008, 2012, color='red', alpha=0.2, label="2008 Financial Crisis")
plt.axvspan(2019, 2024, color='blue', alpha=0.2, label="COVID-19 Pandemic")

# Graph details
plt.title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Unemployment Rate (%)", fontsize=12)
plt.xticks(yearly_averages["year"], rotation=45)
plt.grid(axis='y', alpha=0.3)
plt.legend()
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    ((unemployment_data["observation_date"] >= "2007-01-01") & (unemployment_data["observation_date"] <= "2012-12-31")) |
    ((unemployment_data["observation_date"] >= "2019-01-01") & (unemployment_data["observation_date"] <= "2024-12-31"))
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Apply Seaborn style
sns.set_theme(style="whitegrid")

# Bar Chart with Seaborn Effects
plt.figure(figsize=(12, 6))
barplot = sns.barplot(
    x="year", 
    y="UNRATE", 
    data=yearly_averages, 
    palette="coolwarm", 
    edgecolor="black"
)

# Add annotations to each bar
for index, row in yearly_averages.iterrows():
    plt.text(row.name, row.UNRATE + 0.2, f"{row.UNRATE:.2f}%", ha='center', fontsize=10)

# Highlight crisis periods with background shading
plt.axvspan(1.5, 5.5, color='gray', alpha=0.2, label="2008 Financial Crisis")
plt.axvspan(12.5, 17.5, color='gray', alpha=0.2, label="COVID-19 Pandemic")

# Graph details
plt.title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=16, fontweight='bold')
plt.xlabel("Year", fontsize=14)
plt.ylabel("Unemployment Rate (%)", fontsize=14)
plt.xticks(rotation=45)
plt.legend(loc="upper right", fontsize=12)
plt.tight_layout()

plt.show()
# Out:
# /var/folders/_c/wwh4ntjd79zgv89r7tdw_dwc0000gn/T/ipykernel_56717/2415687244.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    ((unemployment_data["observation_date"] >= "2007-01-01") & (unemployment_data["observation_date"] <= "2012-12-31")) |
    ((unemployment_data["observation_date"] >= "2019-01-01") & (unemployment_data["observation_date"] <= "2024-12-31"))
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Normalize unemployment rates for color intensity (min-max scaling)
yearly_averages["color_intensity"] = (yearly_averages["UNRATE"] - yearly_averages["UNRATE"].min()) / (
    yearly_averages["UNRATE"].max() - yearly_averages["UNRATE"].min()
)

# Bar Chart with Gradient-Based Coloring
plt.figure(figsize=(12, 6))
colors = sns.light_palette("grey", as_cmap=True)

bars = plt.bar(
    yearly_averages["year"], 
    yearly_averages["UNRATE"], 
    color=[colors(rate) for rate in yearly_averages["color_intensity"]], 
    edgecolor="black"
)

# Add annotations to each bar
for bar, rate in zip(bars, yearly_averages["UNRATE"]):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.2, f"{rate:.2f}%", ha='center', fontsize=10)

# Graph details
plt.title("U.S. Yearly Average Unemployment Rate (2007–2024) with Gradient Intensity", fontsize=16, fontweight="bold")
plt.xlabel("Year", fontsize=14)
plt.ylabel("Unemployment Rate (%)", fontsize=14)
plt.xticks(yearly_averages["year"], rotation=45)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    ((unemployment_data["observation_date"] >= "2007-01-01") & (unemployment_data["observation_date"] <= "2012-12-31")) |
    ((unemployment_data["observation_date"] >= "2019-01-01") & (unemployment_data["observation_date"] <= "2024-12-31"))
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Define crisis years
crisis_years = list(range(2008, 2013)) + list(range(2020, 2024))
yearly_averages["color"] = yearly_averages["year"].apply(
    lambda x: "red" if x in crisis_years else "blue"
)

# Bar Chart with Crisis Years Highlighted
plt.figure(figsize=(12, 6))
bars = plt.bar(
    yearly_averages["year"], 
    yearly_averages["UNRATE"], 
    color=yearly_averages["color"], 
    edgecolor="black"
)

# Add annotations to each bar
for bar, rate in zip(bars, yearly_averages["UNRATE"]):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.2, f"{rate:.2f}%", ha='center', fontsize=10)

# Graph details
plt.title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=16, fontweight="bold")
plt.xlabel("Year", fontsize=14)
plt.ylabel("Unemployment Rate (%)", fontsize=14)
plt.xticks(yearly_averages["year"], rotation=45)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()

# Add legend
plt.legend(["Crisis Years", "Non-Crisis Years"], loc="upper right", fontsize=12)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    ((unemployment_data["observation_date"] >= "2007-01-01") & (unemployment_data["observation_date"] <= "2012-12-31")) |
    ((unemployment_data["observation_date"] >= "2019-01-01") & (unemployment_data["observation_date"] <= "2024-12-31"))
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Define crisis years
crisis_years = list(range(2008, 2013)) + list(range(2020, 2024))
yearly_averages["color"] = yearly_averages["year"].apply(
    lambda x: "#FF6F61" if x in crisis_years else "#6B8E23"
)

# Horizontal Bar Chart
plt.figure(figsize=(14, 8))
bars = plt.barh(
    yearly_averages["year"].astype(str), 
    yearly_averages["UNRATE"], 
    color=yearly_averages["color"], 
    edgecolor="black"
)

# Add gradient background
gradient = mcolors.LinearSegmentedColormap.from_list("gradient", ["#e0f7fa", "#80deea"])
plt.imshow([[0, 1], [0, 1]], extent=[0, yearly_averages["UNRATE"].max() + 1, -1, len(yearly_averages)], cmap=gradient, aspect='auto', alpha=0.3)

# Add annotations
for bar, rate in zip(bars, yearly_averages["UNRATE"]):
    plt.text(rate + 0.2, bar.get_y() + bar.get_height() / 2, f"{rate:.2f}%", va='center', fontsize=12)

# Graph details
plt.title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=20, fontweight="bold", color="#4B0082")
plt.xlabel("Unemployment Rate (%)", fontsize=16, fontweight="bold", color="#4B0082")
plt.ylabel("Year", fontsize=16, fontweight="bold", color="#4B0082")
plt.grid(axis='x', linestyle="--", alpha=0.5)

# Add legend
plt.legend(["Crisis Years (Red)", "Non-Crisis Years (Green)"], loc="upper right", fontsize=12, frameon=True)

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    ((unemployment_data["observation_date"] >= "2007-01-01") & (unemployment_data["observation_date"] <= "2012-12-31")) |
    ((unemployment_data["observation_date"] >= "2019-01-01") & (unemployment_data["observation_date"] <= "2024-12-31"))
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Normalize unemployment rates for color intensity (min-max scaling)
yearly_averages["color_intensity"] = (yearly_averages["UNRATE"] - yearly_averages["UNRATE"].min()) / (
    yearly_averages["UNRATE"].max() - yearly_averages["UNRATE"].min()
)

# Gradient color for bars
colors = plt.cm.viridis(yearly_averages["color_intensity"])

# Vertical Bar Chart
plt.figure(figsize=(14, 8))
bars = plt.bar(
    yearly_averages["year"], 
    yearly_averages["UNRATE"], 
    color=colors, 
    edgecolor="black"
)

# Add annotations
for bar, rate in zip(bars, yearly_averages["UNRATE"]):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.2, f"{rate:.2f}%", ha='center', fontsize=12)

# Graph details
plt.title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=20, fontweight="bold", color="#4B0082")
plt.xlabel("Year", fontsize=16, fontweight="bold", color="#4B0082")
plt.ylabel("Unemployment Rate (%)", fontsize=16, fontweight="bold", color="#4B0082")
plt.xticks(yearly_averages["year"], rotation=45)
plt.grid(axis='y', linestyle="--", alpha=0.5)

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    (unemployment_data["observation_date"] >= "2007-01-01") & 
    (unemployment_data["observation_date"] <= "2024-12-31")
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Normalize unemployment rates for color intensity (min-max scaling)
yearly_averages["color_intensity"] = (yearly_averages["UNRATE"] - yearly_averages["UNRATE"].min()) / (
    yearly_averages["UNRATE"].max() - yearly_averages["UNRATE"].min()
)

# Gradient color for bars (green gradient)
colors = plt.cm.Greens(yearly_averages["color_intensity"])

# Vertical Bar Chart
plt.figure(figsize=(14, 8))
bars = plt.bar(
    yearly_averages["year"], 
    yearly_averages["UNRATE"], 
    color=colors, 
    edgecolor="black"
)

# Add annotations
for bar, rate in zip(bars, yearly_averages["UNRATE"]):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.2, f"{rate:.2f}%", ha='center', fontsize=10)

# Graph details
plt.title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=20, fontweight="bold", color="#2E7D32")
plt.xlabel("Year", fontsize=16, fontweight="bold", color="#2E7D32")
plt.ylabel("Unemployment Rate (%)", fontsize=16, fontweight="bold", color="#2E7D32")
plt.xticks(yearly_averages["year"], rotation=45)
plt.grid(axis='y', linestyle="--", alpha=0.5)

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    (unemployment_data["observation_date"] >= "2007-01-01") & 
    (unemployment_data["observation_date"] <= "2024-12-31")
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Normalize unemployment rates for color intensity (min-max scaling)
yearly_averages["color_intensity"] = (yearly_averages["UNRATE"] - yearly_averages["UNRATE"].min()) / (
    yearly_averages["UNRATE"].max() - yearly_averages["UNRATE"].min()
)

# Gradient color for bars (green gradient)
colors = plt.cm.Greens(yearly_averages["color_intensity"])

# Crisis periods
crisis_periods = [(2008, 2012), (2020, 2023)]

# Vertical Bar Chart
plt.figure(figsize=(14, 8))

# Add background shading for crisis periods
for start, end in crisis_periods:
    plt.axvspan(start - 0.5, end + 0.5, color="lightgray", alpha=0.3)

# Plot bars
bars = plt.bar(
    yearly_averages["year"], 
    yearly_averages["UNRATE"], 
    color=colors, 
    edgecolor="black"
)

# Add annotations
for bar, rate in zip(bars, yearly_averages["UNRATE"]):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.2, f"{rate:.2f}%", ha='center', fontsize=10)

# Graph details
plt.title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=20, fontweight="bold", color="#2E7D32")
plt.xlabel("Year", fontsize=16, fontweight="bold", color="#2E7D32")
plt.ylabel("Unemployment Rate (%)", fontsize=16, fontweight="bold", color="#2E7D32")
plt.xticks(yearly_averages["year"], rotation=45)
plt.grid(axis='y', linestyle="--", alpha=0.5)

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    (unemployment_data["observation_date"] >= "2007-01-01") & 
    (unemployment_data["observation_date"] <= "2024-12-31")
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Normalize unemployment rates for color intensity (min-max scaling)
norm = plt.Normalize(yearly_averages["UNRATE"].min(), yearly_averages["UNRATE"].max())
colors = plt.cm.Blues(norm(yearly_averages["UNRATE"]))

# Crisis periods
crisis_periods = [(2008, 2012), (2020, 2023)]

# Create the figure
fig, ax = plt.subplots(figsize=(14, 8))

# Add background shading for crisis periods
for start, end in crisis_periods:
    ax.axvspan(start - 0.5, end + 0.5, color="lightgray", alpha=0.3)

# Plot bars
bars = ax.bar(
    yearly_averages["year"], 
    yearly_averages["UNRATE"], 
    color=colors, 
    edgecolor="black"
)

# Add annotations
for bar, rate in zip(bars, yearly_averages["UNRATE"]):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.2, f"{rate:.2f}%", ha='center', fontsize=10)

# Add color bar for explanation
sm = plt.cm.ScalarMappable(cmap="Blues", norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, orientation="vertical", pad=0.02)
cbar.set_label("Unemployment Rate (%)", fontsize=14, fontweight="bold", color="#1f4e79")

# Graph details
ax.set_title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=20, fontweight="bold", color="#1f4e79")
ax.set_xlabel("Year", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_ylabel("Unemployment Rate (%)", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_xticks(yearly_averages["year"])
ax.set_xticklabels(yearly_averages["year"], rotation=45)
ax.grid(axis='y', linestyle="--", alpha=0.5)

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    (unemployment_data["observation_date"] >= "2007-01-01") & 
    (unemployment_data["observation_date"] <= "2024-12-31")
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Normalize unemployment rates for color intensity (min-max scaling)
norm = plt.Normalize(yearly_averages["UNRATE"].min(), yearly_averages["UNRATE"].max())
colors = plt.cm.Blues(norm(yearly_averages["UNRATE"]))

# Define crisis labels and ranges
crisis_labels = [
    {"label": "2008 Financial Crisis", "start": 2008, "end": 2012},
    {"label": "COVID-19 Pandemic", "start": 2020, "end": 2023}
]

# Create the figure
fig, ax = plt.subplots(figsize=(14, 8))

# Plot bars
bars = ax.bar(
    yearly_averages["year"], 
    yearly_averages["UNRATE"], 
    color=colors, 
    edgecolor="black"
)

# Add annotations for unemployment rates
for bar, rate in zip(bars, yearly_averages["UNRATE"]):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.2, f"{rate:.2f}%", ha='center', fontsize=10)

# Add crisis labels on top
for crisis in crisis_labels:
    start = crisis["start"] - 0.5
    end = crisis["end"] + 0.5
    mid = (start + end) / 2
    ax.annotate(
        crisis["label"], 
        xy=(mid, max(yearly_averages["UNRATE"]) + 1.5), 
        ha='center', 
        fontsize=12, 
        fontweight="bold", 
        color="red",
        arrowprops=dict(arrowstyle="|-|", color="red", lw=1.5),
        xytext=(mid, max(yearly_averages["UNRATE"]) + 2)
    )

# Graph details
ax.set_title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=20, fontweight="bold", color="#1f4e79")
ax.set_xlabel("Year", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_ylabel("Unemployment Rate (%)", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_xticks(yearly_averages["year"])
ax.set_xticklabels(yearly_averages["year"], rotation=45)
ax.grid(axis='y', linestyle="--", alpha=0.5)

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    (unemployment_data["observation_date"] >= "2007-01-01") & 
    (unemployment_data["observation_date"] <= "2024-12-31")
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Normalize unemployment rates for color intensity (min-max scaling)
norm = plt.Normalize(yearly_averages["UNRATE"].min(), yearly_averages["UNRATE"].max())
colors = plt.cm.Blues(norm(yearly_averages["UNRATE"]))

# Define crisis labels and ranges
crisis_labels = [
    {"label": "2008 Financial Crisis", "start": 2008, "end": 2012},
    {"label": "COVID-19 Pandemic", "start": 2020, "end": 2023}
]

# Create the figure
fig, ax = plt.subplots(figsize=(14, 8))

# Plot bars
bars = ax.bar(
    yearly_averages["year"], 
    yearly_averages["UNRATE"], 
    color=colors, 
    edgecolor="black"
)

# Add annotations for unemployment rates
for bar, rate in zip(bars, yearly_averages["UNRATE"]):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.2, f"{rate:.2f}%", ha='center', fontsize=10)

# Add crisis labels on top
for crisis in crisis_labels:
    start = crisis["start"] - 0.5
    end = crisis["end"] + 0.5
    mid = (start + end) / 2
    ax.annotate(
        crisis["label"], 
        xy=(mid, max(yearly_averages["UNRATE"]) + 1.5), 
        ha='center', 
        fontsize=12, 
        fontweight="bold", 
        color="red",
        arrowprops=dict(arrowstyle="|-|", color="red", lw=1.5),
        xytext=(mid, max(yearly_averages["UNRATE"]) + 2)
    )

# Graph details
ax.set_title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=20, fontweight="bold", color="#1f4e79")
ax.set_xlabel("Year", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_ylabel("Unemployment Rate (%)", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_xticks(yearly_averages["year"])
ax.set_xticklabels(yearly_averages["year"], rotation=45)
ax.grid(axis='y', linestyle="--", alpha=0.5)

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    (unemployment_data["observation_date"] >= "2007-01-01") & 
    (unemployment_data["observation_date"] <= "2024-12-31")
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Normalize unemployment rates for color intensity (min-max scaling)
norm = plt.Normalize(yearly_averages["UNRATE"].min(), yearly_averages["UNRATE"].max())
colors = plt.cm.Blues(norm(yearly_averages["UNRATE"]))

# Define crisis labels and ranges
crisis_labels = [
    {"label": "2008 Financial Crisis", "start": 2008, "end": 2012},
    {"label": "COVID-19 Pandemic", "start": 2020, "end": 2023}
]

# Create the figure
fig, ax = plt.subplots(figsize=(14, 8))

# Plot bars
bars = ax.bar(
    yearly_averages["year"], 
    yearly_averages["UNRATE"], 
    color=colors, 
    edgecolor="black"
)

# Add annotations for unemployment rates
for bar, rate in zip(bars, yearly_averages["UNRATE"]):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.2, f"{rate:.2f}%", ha='center', fontsize=10)

# Add crisis labels on top
for crisis in crisis_labels:
    start = crisis["start"] - 0.5
    end = crisis["end"] + 0.5
    mid = (start + end) / 2
    ax.annotate(
        crisis["label"], 
        xy=(mid, max(yearly_averages["UNRATE"]) + 1.5), 
        ha='center', 
        fontsize=12, 
        fontweight="bold", 
        color="red",
        arrowprops=dict(arrowstyle="|-|", color="red", lw=1.5),
        xytext=(mid, max(yearly_averages["UNRATE"]) + 2)
    )

# Graph details
ax.set_title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=20, fontweight="bold", color="#1f4e79")
ax.set_xlabel("Year", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_ylabel("Unemployment Rate (%)", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_xticks(yearly_averages["year"])
ax.set_xticklabels(yearly_averages["year"], rotation=45)
ax.grid(axis='y', linestyle="--", alpha=0.5)

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    (unemployment_data["observation_date"] >= "2007-01-01") & 
    (unemployment_data["observation_date"] <= "2024-12-31")
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Normalize unemployment rates for color intensity (min-max scaling)
norm = plt.Normalize(yearly_averages["UNRATE"].min(), yearly_averages["UNRATE"].max())
colors = plt.cm.Blues(norm(yearly_averages["UNRATE"]))

# Define crisis labels and ranges
crisis_labels = [
    {"label": "2008 Financial Crisis", "start": 2008, "end": 2012},
    {"label": "COVID-19 Pandemic", "start": 2020, "end": 2023}
]

# Create the figure
fig, ax = plt.subplots(figsize=(14, 8))

# Plot bars
bars = ax.bar(
    yearly_averages["year"], 
    yearly_averages["UNRATE"], 
    color=colors, 
    edgecolor="black"
)

# Add annotations for unemployment rates
for bar, rate in zip(bars, yearly_averages["UNRATE"]):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.2, f"{rate:.2f}%", ha='center', fontsize=10)

# Add crisis labels on top
for crisis in crisis_labels:
    start = crisis["start"] - 0.5
    end = crisis["end"] + 0.5
    mid = (start + end) / 2
    ax.annotate(
        crisis["label"], 
        xy=(mid, max(yearly_averages["UNRATE"]) + 1.5), 
        ha='center', 
        fontsize=12, 
        fontweight="bold", 
        color="red",
        arrowprops=dict(arrowstyle="|-|", color="red", lw=1.5),
        xytext=(mid, max(yearly_averages["UNRATE"]) + 2)
    )

# Explanation of crisis years
crisis_text = (
    "Highlighted crisis periods:\n"
    "- 2008 Financial Crisis: 2008–2012\n"
    "- COVID-19 Pandemic: 2020–2023\n"
    "The background annotations identify periods of major economic disruptions."
)
plt.figtext(0.99, 0.2, crisis_text, fontsize=12, color="darkblue", ha="right")

# Graph details
ax.set_title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=20, fontweight="bold", color="#1f4e79")
ax.set_xlabel("Year", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_ylabel("Unemployment Rate (%)", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_xticks(yearly_averages["year"])
ax.set_xticklabels(yearly_averages["year"], rotation=45)
ax.grid(axis='y', linestyle="--", alpha=0.5)

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    (unemployment_data["observation_date"] >= "2007-01-01") & 
    (unemployment_data["observation_date"] <= "2024-12-31")
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Normalize unemployment rates for color intensity (min-max scaling)
norm = plt.Normalize(yearly_averages["UNRATE"].min(), yearly_averages["UNRATE"].max())
colors = plt.cm.Blues(norm(yearly_averages["UNRATE"]))

# Define crisis labels and ranges
crisis_labels = [
    {"label": "2008 Financial Crisis", "start": 2008, "end": 2012},
    {"label": "COVID-19 Pandemic", "start": 2020, "end": 2023}
]

# Create the figure
fig, ax = plt.subplots(figsize=(14, 8))

# Plot bars
bars = ax.bar(
    yearly_averages["year"], 
    yearly_averages["UNRATE"], 
    color=colors, 
    edgecolor="black"
)

# Add annotations for unemployment rates
for bar, rate in zip(bars, yearly_averages["UNRATE"]):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.2, f"{rate:.2f}%", ha='center', fontsize=10)

# Add crisis labels on top
for crisis in crisis_labels:
    start = crisis["start"] - 0.5
    end = crisis["end"] + 0.5
    mid = (start + end) / 2
    ax.annotate(
        crisis["label"], 
        xy=(mid, max(yearly_averages["UNRATE"]) + 1.5), 
        ha='center', 
        fontsize=12, 
        fontweight="bold", 
        color="red",
        arrowprops=dict(arrowstyle="|-|", color="red", lw=1.5),
        xytext=(mid, max(yearly_averages["UNRATE"]) + 2)
    )

# Explanation of crisis years
crisis_text = (
    "Highlighted crisis periods:\n"
    "- 2008 Financial Crisis: 2008–2012\n"
    "- COVID-19 Pandemic: 2020–2023\n"
    "The background annotations identify periods of major economic disruptions."
)
plt.figtext(0.99, 0.2, crisis_text, fontsize=12, color="darkblue", ha="right")

# Graph details
ax.set_title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=20, fontweight="bold", color="#1f4e79")
ax.set_xlabel("Year", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_ylabel("Unemployment Rate (%)", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_xticks(yearly_averages["year"])
ax.set_xticklabels(yearly_averages["year"], rotation=45)
ax.grid(axis='y', linestyle="--", alpha=0.5)

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    (unemployment_data["observation_date"] >= "2007-01-01") & 
    (unemployment_data["observation_date"] <= "2024-12-31")
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Normalize unemployment rates for color intensity (min-max scaling)
norm = plt.Normalize(yearly_averages["UNRATE"].min(), yearly_averages["UNRATE"].max())
colors = plt.cm.Blues(norm(yearly_averages["UNRATE"]))

# Crisis periods with differentiated colors
crisis_periods = [
    {"label": "2008 Financial Crisis", "start": 2008, "end": 2012, "color": "lightgrey"},
    {"label": "COVID-19 Pandemic", "start": 2020, "end": 2023, "color": "lightblue"}
]

# Create the figure
fig, ax = plt.subplots(figsize=(14, 8))

# Add background shading for crisis periods
for crisis in crisis_periods:
    ax.axvspan(crisis["start"] - 0.5, crisis["end"] + 0.5, color=crisis["color"], alpha=0.3, label=crisis["label"])

# Plot bars
bars = ax.bar(
    yearly_averages["year"], 
    yearly_averages["UNRATE"], 
    color=colors, 
    edgecolor="black"
)

# Add annotations for unemployment rates
for bar, rate in zip(bars, yearly_averages["UNRATE"]):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.2, f"{rate:.2f}%", ha='center', fontsize=10)

# Add text annotations for crisis labels
for crisis in crisis_periods:
    mid = (crisis["start"] + crisis["end"]) / 2
    ax.annotate(
        crisis["label"], 
        xy=(mid, max(yearly_averages["UNRATE"]) + 1), 
        ha="center", 
        fontsize=12, 
        fontweight="bold", 
        color=crisis["color"],
        arrowprops=dict(arrowstyle="|-|", color=crisis["color"], lw=1.5),
        xytext=(mid, max(yearly_averages["UNRATE"]) + 2)
    )

# Add color bar for explanation
sm = plt.cm.ScalarMappable(cmap="Blues", norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, orientation="vertical", pad=0.02)
cbar.set_label("Unemployment Rate (%)", fontsize=14, fontweight="bold", color="#1f4e79")

# Graph details
ax.set_title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=20, fontweight="bold", color="#1f4e79")
ax.set_xlabel("Year", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_ylabel("Unemployment Rate (%)", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_xticks(yearly_averages["year"])
ax.set_xticklabels(yearly_averages["year"], rotation=45)
ax.grid(axis='y', linestyle="--", alpha=0.5)

# Add legend for crisis shading
ax.legend(loc="upper left", fontsize=12, frameon=True)

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    (unemployment_data["observation_date"] >= "2007-01-01") & 
    (unemployment_data["observation_date"] <= "2024-12-31")
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Normalize unemployment rates for color intensity (min-max scaling)
norm = plt.Normalize(yearly_averages["UNRATE"].min(), yearly_averages["UNRATE"].max())
colors = plt.cm.Blues(norm(yearly_averages["UNRATE"]))

# Crisis periods with differentiated colors
crisis_periods = [
    {"label": "2008 Financial Crisis", "start": 2008, "end": 2012, "color": "lightcoral"},
    {"label": "COVID-19 Pandemic", "start": 2020, "end": 2023, "color": "lightblue"}
]

# Create the figure
fig, ax = plt.subplots(figsize=(14, 8))

# Add background shading for crisis periods
for crisis in crisis_periods:
    ax.axvspan(crisis["start"] - 0.5, crisis["end"] + 0.5, color=crisis["color"], alpha=0.3)

# Plot bars
bars = ax.bar(
    yearly_averages["year"], 
    yearly_averages["UNRATE"], 
    color=colors, 
    edgecolor="black"
)

# Add annotations for unemployment rates
for bar, rate in zip(bars, yearly_averages["UNRATE"]):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.2, f"{rate:.2f}%", ha='center', fontsize=10)

# Add crisis labels on the right
for i, crisis in enumerate(crisis_periods):
    ax.text(
        2025,  # Position beyond the last year
        max(yearly_averages["UNRATE"]) - i * 1.5,  # Offset each label vertically
        f"{crisis['label']}: {crisis['start']}–{crisis['end']}", 
        fontsize=12, 
        color=crisis["color"], 
        fontweight="bold", 
        va="center"
    )

# Add color bar for explanation
sm = plt.cm.ScalarMappable(cmap="Blues", norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, orientation="vertical", pad=0.02)
cbar.set_label("Unemployment Rate (%)", fontsize=14, fontweight="bold", color="#1f4e79")

# Graph details
ax.set_title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=20, fontweight="bold", color="#1f4e79")
ax.set_xlabel("Year", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_ylabel("Unemployment Rate (%)", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_xticks(yearly_averages["year"])
ax.set_xticklabels(yearly_averages["year"], rotation=45)
ax.grid(axis='y', linestyle="--", alpha=0.5)

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    (unemployment_data["observation_date"] >= "2007-01-01") & 
    (unemployment_data["observation_date"] <= "2024-12-31")
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Normalize unemployment rates for color intensity (min-max scaling)
norm = plt.Normalize(yearly_averages["UNRATE"].min(), yearly_averages["UNRATE"].max())
colors = plt.cm.Blues(norm(yearly_averages["UNRATE"]))

# Crisis periods with differentiated colors
crisis_periods = [
    {"label": "2008 Financial Crisis", "start": 2008, "end": 2012, "color": "lightcoral"},
    {"label": "COVID-19 Pandemic", "start": 2020, "end": 2023, "color": "lightblue"}
]

# Create the figure
fig, ax = plt.subplots(figsize=(14, 8))

# Add background shading for crisis periods
for crisis in crisis_periods:
    ax.axvspan(crisis["start"] - 0.5, crisis["end"] + 0.5, color=crisis["color"], alpha=0.3)

# Plot bars
bars = ax.bar(
    yearly_averages["year"], 
    yearly_averages["UNRATE"], 
    color=colors, 
    edgecolor="black"
)

# Add annotations for unemployment rates
for bar, rate in zip(bars, yearly_averages["UNRATE"]):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.2, f"{rate:.2f}%", ha='center', fontsize=10)

# Add crisis labels inside the graph on the right
for i, crisis in enumerate(crisis_periods):
    ax.text(
        2024.5,  # Position inside the graph on the far right
        max(yearly_averages["UNRATE"]) - i * 1.5,  # Offset each label vertically
        f"{crisis['label']}: {crisis['start']}–{crisis['end']}", 
        fontsize=12, 
        color=crisis["color"], 
        fontweight="bold", 
        va="center"
    )

# Add color bar for explanation
sm = plt.cm.ScalarMappable(cmap="Blues", norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, orientation="vertical", pad=0.02)
cbar.set_label("Unemployment Rate (%)", fontsize=14, fontweight="bold", color="#1f4e79")

# Graph details
ax.set_title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=20, fontweight="bold", color="#1f4e79")
ax.set_xlabel("Year", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_ylabel("Unemployment Rate (%)", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_xticks(yearly_averages["year"])
ax.set_xticklabels(yearly_averages["year"], rotation=45)
ax.grid(axis='y', linestyle="--", alpha=0.5)

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods and explicitly create a copy
filtered_data = unemployment_data[
    (unemployment_data["observation_date"] >= "2007-01-01") & 
    (unemployment_data["observation_date"] <= "2024-12-31")
].copy()

# Safely add the 'year' column
filtered_data["year"] = filtered_data["observation_date"].dt.year

# Create yearly averages
yearly_averages = filtered_data.groupby("year")["UNRATE"].mean().reset_index()

# Normalize unemployment rates for color intensity (min-max scaling)
norm = plt.Normalize(yearly_averages["UNRATE"].min(), yearly_averages["UNRATE"].max())
colors = plt.cm.Blues(norm(yearly_averages["UNRATE"]))

# Crisis periods with differentiated colors
crisis_periods = [
    {"label": "2008 Financial Crisis", "start": 2008, "end": 2012, "color": "lightgrey"},
    {"label": "COVID-19 Pandemic", "start": 2020, "end": 2023, "color": "lightblue"}
]

# Create the figure
fig, ax = plt.subplots(figsize=(14, 8))

# Add background shading for crisis periods
for crisis in crisis_periods:
    ax.axvspan(crisis["start"] - 0.5, crisis["end"] + 0.5, color=crisis["color"], alpha=0.3, label=crisis["label"])

# Plot bars
bars = ax.bar(
    yearly_averages["year"], 
    yearly_averages["UNRATE"], 
    color=colors, 
    edgecolor="black"
)

# Add annotations for unemployment rates
for bar, rate in zip(bars, yearly_averages["UNRATE"]):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.2, f"{rate:.2f}%", ha='center', fontsize=10)

# Add text annotations for crisis labels
for crisis in crisis_periods:
    mid = (crisis["start"] + crisis["end"]) / 2
    ax.annotate(
        crisis["label"], 
        xy=(mid, max(yearly_averages["UNRATE"]) + 1), 
        ha="center", 
        fontsize=12, 
        fontweight="bold", 
        color=crisis["color"],
        arrowprops=dict(arrowstyle="|-|", color=crisis["color"], lw=1.5),
        xytext=(mid, max(yearly_averages["UNRATE"]) + 2)
    )

# Add color bar for explanation
sm = plt.cm.ScalarMappable(cmap="Blues", norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, orientation="vertical", pad=0.02)
cbar.set_label("Unemployment Rate (%)", fontsize=14, fontweight="bold", color="#1f4e79")

# Graph details
ax.set_title("U.S. Yearly Average Unemployment Rate (2007–2024)", fontsize=20, fontweight="bold", color="#1f4e79")
ax.set_xlabel("Year", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_ylabel("Unemployment Rate (%)", fontsize=16, fontweight="bold", color="#1f4e79")
ax.set_xticks(yearly_averages["year"])
ax.set_xticklabels(yearly_averages["year"], rotation=45)
ax.grid(axis='y', linestyle="--", alpha=0.5)

# Add legend for crisis shading
ax.legend(loc="upper right", fontsize=12, frameon=True)

# Adjust layout
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the unemployment dataset
unemployment_data = pd.read_csv("UNRATE (2).csv")

# Convert observation_date to datetime
unemployment_data["observation_date"] = pd.to_datetime(unemployment_data["observation_date"])

# Filter for relevant time periods: 2007–2012 and 2019–2024
filtered_data = unemployment_data[
    ((unemployment_data["observation_date"] >= "2007-01-01") & (unemployment_data["observation_date"] <= "2012-12-31")) |
    ((unemployment_data["observation_date"] >= "2019-01-01") & (unemployment_data["observation_date"] <= "2024-12-31"))
]

# Line Graph: Monthly Unemployment Rates Over Time
plt.figure(figsize=(12, 6))
plt.plot(filtered_data["observation_date"], filtered_data["UNRATE"], marker='o', linestyle='-', label="Monthly Unemployment Rate")

# Highlight recession periods
plt.axvspan("2008-01-01", "2009-06-01", color='red', alpha=0.2, label="2008 Financial Crisis")
plt.axvspan("2020-03-01", "2020-12-01", color='blue', alpha=0.2, label="COVID-19 Pandemic")

# Graph details
plt.title("U.S. Monthly Unemployment Rate (2007–2012 & 2019–2024)", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Unemployment Rate (%)", fontsize=12)
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

# Plot the GDP and percentage change with highlighted areas
fig, ax1 = plt.subplots(figsize=(14, 8))

# Plot GDP (blue line)
ax1.plot(datas['observation_date'], gdp_in_trillions, color='blue', linestyle='-', linewidth=2, label='GDP (Trillions)')
ax1.set_ylabel('GDP (in trillions $)', fontsize=14, color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.grid(True, linestyle='--', alpha=0.7)

# Secondary y-axis for percentage change
ax2 = ax1.twinx()
ax2.plot(data['observation_date'], data['Percent_Change'], color='orange', linestyle='-', linewidth=2, label='GDP Percent Change')
ax2.set_ylabel('Percent Change (%)', fontsize=14, color='orange')
ax2.tick_params(axis='y', labelcolor='orange')

# Highlight the Great Recession period
ax1.fill_between(recession_dates, gdp_in_trillions.min(), gdp_in_trillions.max(), color='red', alpha=0.3, label='Great Recession (2007-2012)', transform=ax1.get_xaxis_transform())
ax1.annotate('Great Recession', xy=('2009-01-01', gdp_in_trillions.min() + 0.1),
             xycoords='data', color='red', fontsize=12, ha='center')

# Highlight the COVID-19 period
ax1.fill_between(covid_dates, gdp_in_trillions.min(), gdp_in_trillions.max(), color='green', alpha=0.3, label='COVID-19 Period (2019-2024)', transform=ax1.get_xaxis_transform())
ax1.annotate('COVID-19 Pandemic', xy=('2021-01-01', gdp_in_trillions.min() + 0.1),
             xycoords='data', color='green', fontsize=12, ha='center')

# Adding title and labels
fig.suptitle('GDP (Trillions) and Percent Change with Key Economic Events', fontsize=18)
ax1.set_xlabel('Quarter', fontsize=14)

# Improve x-axis readability with quarterly ticks
quarterly_ticks = data['observation_date'].dt.to_period('Q').unique()
ax1.set_xticks(data['observation_date'][::3])
ax1.set_xticklabels(quarterly_ticks[::3].strftime('%Y-Q%q'), rotation=45, fontsize=10)

# Add legend for both axes
fig.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.1, 0.9))

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 7
#       4 fig, ax1 = plt.subplots(figsize=(14, 8))
#       6 # Plot GDP (blue line)
# ----> 7 ax1.plot(datas['observation_date'], gdp_in_trillions, color='blue', linestyle='-', linewidth=2, label='GDP (Trillions)')
#       8 ax1.set_ylabel('GDP (in trillions $)', fontsize=14, color='blue')
#       9 ax1.tick_params(axis='y', labelcolor='blue')
#
# NameError: name 'datas' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the GDP dataset
data = pd.read_csv("GDP.csv")

# Convert observation_date to datetime
data['observation_date'] = pd.to_datetime(data['observation_date'])

# Calculate GDP in trillions
data['GDP_in_Trillions'] = data['GDP'] / 1000

# Calculate percentage change
data['Percent_Change'] = data['GDP'].pct_change() * 100

# Define crisis periods
recession_dates = (data['observation_date'] >= '2007-01-01') & (data['observation_date'] <= '2012-12-31')
covid_dates = (data['observation_date'] >= '2019-01-01') & (data['observation_date'] <= '2024-12-31')

# Plot the GDP and percentage change with highlighted areas
fig, ax1 = plt.subplots(figsize=(14, 8))

# Plot GDP (blue line)
ax1.plot(data['observation_date'], data['GDP_in_Trillions'], color='blue', linestyle='-', linewidth=2, label='GDP (Trillions)')
ax1.set_ylabel('GDP (in Trillions $)', fontsize=14, color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.grid(True, linestyle='--', alpha=0.7)

# Secondary y-axis for percentage change
ax2 = ax1.twinx()
ax2.plot(data['observation_date'], data['Percent_Change'], color='orange', linestyle='-', linewidth=2, label='GDP Percent Change')
ax2.set_ylabel('Percent Change (%)', fontsize=14, color='orange')
ax2.tick_params(axis='y', labelcolor='orange')

# Highlight the Great Recession period
ax1.fill_between(data['observation_date'], data['GDP_in_Trillions'].min(), data['GDP_in_Trillions'].max(), 
                 where=recession_dates, color='red', alpha=0.3, label='Great Recession (2007-2012)')
ax1.annotate('Great Recession', xy=('2009-01-01', data['GDP_in_Trillions'].min() + 0.1),
             xycoords='data', color='red', fontsize=12, ha='center')

# Highlight the COVID-19 period
ax1.fill_between(data['observation_date'], data['GDP_in_Trillions'].min(), data['GDP_in_Trillions'].max(), 
                 where=covid_dates, color='green', alpha=0.3, label='COVID-19 Period (2019-2024)')
ax1.annotate('COVID-19 Pandemic', xy=('2021-01-01', data['GDP_in_Trillions'].min() + 0.1),
             xycoords='data', color='green', fontsize=12, ha='center')

# Adding title and labels
fig.suptitle('GDP (Trillions) and Percent Change with Key Economic Events', fontsize=18)
ax1.set_xlabel('Quarter', fontsize=14)

# Improve x-axis readability with quarterly ticks
quarterly_ticks = data['observation_date'][::3]
ax1.set_xticks(quarterly_ticks)
ax1.set_xticklabels(data['observation_date'][::3].dt.strftime('%Y-Q%q'), rotation=45, fontsize=10)

# Add legend for both axes
fig.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.1, 0.9))

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axis.py:1769, in Axis.convert_units(self, x)
#    1768 try:
# -> 1769     ret = self.converter.convert(x, self.units, self)
#    1770 except Exception as e:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/dates.py:1888, in _SwitchableDateConverter.convert(self, *args, **kwargs)
#    1887 def convert(self, *args, **kwargs):
# -> 1888     return self._get_converter().convert(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/dates.py:1816, in DateConverter.convert(value, unit, axis)
#    1810 """
#    1811 If *value* is not already a number or sequence of numbers, convert it
#    1812 with `date2num`.
#    1813
#    1814 The *unit* and *axis* arguments are not used.
#    1815 """
# -> 1816 return date2num(value)
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the GDP dataset
data = pd.read_csv("GDP.csv")

# Convert observation_date to datetime
data['observation_date'] = pd.to_datetime(data['observation_date'])

# Calculate GDP in trillions
data['GDP_in_Trillions'] = data['GDP'] / 1000

# Calculate percentage change
data['Percent_Change'] = data['GDP'].pct_change() * 100

# Define crisis periods as datetime ranges
recession_start, recession_end = pd.Timestamp('2007-01-01'), pd.Timestamp('2012-12-31')
covid_start, covid_end = pd.Timestamp('2019-01-01'), pd.Timestamp('2024-12-31')

# Plot the GDP and percentage change with highlighted areas
fig, ax1 = plt.subplots(figsize=(14, 8))

# Plot GDP (blue line)
ax1.plot(data['observation_date'], data['GDP_in_Trillions'], color='blue', linestyle='-', linewidth=2, label='GDP (Trillions)')
ax1.set_ylabel('GDP (in Trillions $)', fontsize=14, color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.grid(True, linestyle='--', alpha=0.7)

# Secondary y-axis for percentage change
ax2 = ax1.twinx()
ax2.plot(data['observation_date'], data['Percent_Change'], color='orange', linestyle='-', linewidth=2, label='GDP Percent Change')
ax2.set_ylabel('Percent Change (%)', fontsize=14, color='orange')
ax2.tick_params(axis='y', labelcolor='orange')

# Highlight the Great Recession period
ax1.fill_between(
    data['observation_date'], 
    data['GDP_in_Trillions'].min(), 
    data['GDP_in_Trillions'].max(),
    where=(data['observation_date'] >= recession_start) & (data['observation_date'] <= recession_end),
    color='red', alpha=0.3, label='Great Recession (2007-2012)'
)
ax1.annotate(
    'Great Recession', 
    xy=(pd.Timestamp('2009-01-01'), data['GDP_in_Trillions'].min() + 0.1),
    xycoords='data', color='red', fontsize=12, ha='center'
)

# Highlight the COVID-19 period
ax1.fill_between(
    data['observation_date'], 
    data['GDP_in_Trillions'].min(), 
    data['GDP_in_Trillions'].max(),
    where=(data['observation_date'] >= covid_start) & (data['observation_date'] <= covid_end),
    color='green', alpha=0.3, label='COVID-19 Period (2019-2024)'
)
ax1.annotate(
    'COVID-19 Pandemic', 
    xy=(pd.Timestamp('2021-01-01'), data['GDP_in_Trillions'].min() + 0.1),
    xycoords='data', color='green', fontsize=12, ha='center'
)

# Adding title and labels
fig.suptitle('GDP (Trillions) and Percent Change with Key Economic Events', fontsize=18)
ax1.set_xlabel('Quarter', fontsize=14)

# Improve x-axis readability with quarterly ticks
ax1.set_xticks(data['observation_date'][::12])
ax1.set_xticklabels(data['observation_date'][::12].dt.strftime('%Y-Q%q'), rotation=45, fontsize=10)

# Add legend for both axes
fig.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.1, 0.9))

# Display the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the GDP dataset
data = pd.read_csv("GDP.csv")

# Convert observation_date to datetime
data['observation_date'] = pd.to_datetime(data['observation_date'])

# Calculate GDP in trillions
data['GDP_in_Trillions'] = data['GDP'] / 1000

# Calculate percentage change
data['Percent_Change'] = data['GDP'].pct_change() * 100

# Define crisis periods as datetime ranges
recession_start, recession_end = pd.Timestamp('2007-01-01'), pd.Timestamp('2012-12-31')
covid_start, covid_end = pd.Timestamp('2019-01-01'), pd.Timestamp('2024-12-31')

# Plot the GDP and percentage change with highlighted areas
fig, ax1 = plt.subplots(figsize=(14, 8))

# Plot GDP (blue line)
ax1.plot(data['observation_date'], data['GDP_in_Trillions'], color='darkblue', linestyle='-', linewidth=2, label='GDP (Trillions)')
ax1.set_ylabel('GDP (in Trillions $)', fontsize=14, color='darkblue', fontweight='bold')
ax1.tick_params(axis='y', labelcolor='darkblue')
ax1.grid(True, linestyle='--', alpha=0.7)

# Secondary y-axis for percentage change
ax2 = ax1.twinx()
ax2.plot(data['observation_date'], data['Percent_Change'], color='darkgreen', linestyle='-', linewidth=2, label='GDP Percent Change')
ax2.set_ylabel('Percent Change (%)', fontsize=14, color='darkgreen', fontweight='bold')
ax2.tick_params(axis='y', labelcolor='darkgreen')

# Highlight the Great Recession period
ax1.fill_between(
    data['observation_date'], 
    data['GDP_in_Trillions'].min(), 
    data['GDP_in_Trillions'].max(),
    where=(data['observation_date'] >= recession_start) & (data['observation_date'] <= recession_end),
    color='lightblue', alpha=0.3, label='Great Recession (2007-2012)'
)
ax1.annotate(
    'Great Recession', 
    xy=(pd.Timestamp('2009-01-01'), data['GDP_in_Trillions'].min() + 0.1),
    xycoords='data', color='black', fontsize=12, ha='center', fontweight='bold'
)

# Highlight the COVID-19 period
ax1.fill_between(
    data['observation_date'], 
    data['GDP_in_Trillions'].min(), 
    data['GDP_in_Trillions'].max(),
    where=(data['observation_date'] >= covid_start) & (data['observation_date'] <= covid_end),
    color='lightgrey', alpha=0.3, label='COVID-19 Period (2019-2024)'
)
ax1.annotate(
    'COVID-19 Pandemic', 
    xy=(pd.Timestamp('2021-01-01'), data['GDP_in_Trillions'].min() + 0.1),
    xycoords='data', color='black', fontsize=12, ha='left', fontweight='bold'
)

# Adding title and labels
fig.suptitle('GDP (Trillions) and Percent Change with Key Economic Events', fontsize=18, fontweight='bold')
ax1.set_xlabel('Quarter', fontsize=14, fontweight='bold')

# Improve x-axis readability with quarterly ticks
ax1.set_xticks(data['observation_date'][::12])
ax1.set_xticklabels(data['observation_date'][::12].dt.strftime('%Y-Q%q'), rotation=45, fontsize=10)

# Add legend for both axes
fig.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.1, 0.9))

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import pandas as pd

# Define a green color gradient for shading with darker crisis colors
green_cmap = cm.get_cmap('Greens', 5)
green_shades = [mcolors.to_hex(green_cmap(i)) for i in range(5)]

# Example data setup (replace with your dataset as needed)
# quarterly_taxes = <your_data_here> (ensure it's a pandas Series with datetime index)

# Define key periods
financial_crisis_start = pd.to_datetime("2007-10-01")
financial_crisis_end = pd.to_datetime("2009-06-30")
covid_crisis_start = pd.to_datetime("2020-01-01")
covid_crisis_end = pd.to_datetime("2021-12-31")

# Plot the Total Taxes over time with quarterly granularity and adjusted green shading
plt.figure(figsize=(14, 8))

# Plot total taxes as a line graph
plt.plot(quarterly_taxes.index, quarterly_taxes, marker='o', color='black', linewidth=2, label="Total Taxes")

# Highlight economic periods with adjusted green shading
plt.axvspan(financial_crisis_start, financial_crisis_end, color=green_shades[4], alpha=0.4, label="2008 Financial Crisis (Darker)")
plt.axvspan(financial_crisis_end, pd.to_datetime("2019-12-31"), color=green_shades[2], alpha=0.3, label="Post-2008 Recovery")
plt.axvspan(covid_crisis_start, covid_crisis_end, color=green_shades[4], alpha=0.4, label="COVID-19 Crisis (Darker)")
plt.axvspan(covid_crisis_end, quarterly_taxes.index.max(), color=green_shades[2], alpha=0.3, label="Post-COVID Recovery")

# Add titles and labels
plt.title("Total Tax Revenue Trends with Enhanced Shading for Economic and Recovery Periods", fontsize=18, weight='bold')
plt.xlabel("Quarter", fontsize=14)
plt.ylabel("Total Taxes (Billions)", fontsize=14)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=12)
plt.legend(fontsize=12, loc='upper left')
plt.grid(visible=True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/_c/wwh4ntjd79zgv89r7tdw_dwc0000gn/T/ipykernel_56717/4000026696.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   green_cmap = cm.get_cmap('Greens', 5)

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd

# Updated way to get colormap
green_cmap = plt.colormaps.get_cmap('Greens', 5)
green_shades = [mcolors.to_hex(green_cmap(i)) for i in range(5)]

# Example dataset: Replace with your actual dataset
# Ensure quarterly_taxes is a pandas Series with a datetime index
# Example data creation (remove if you already have your data):
data = {
    "Time": pd.date_range(start="2000-01-01", end="2025-01-01", freq="Q"),
    "Total Taxes": [500 + i * 10 for i in range(101)],
}
df = pd.DataFrame(data).set_index("Time")
quarterly_taxes = df["Total Taxes"]

# Define key periods
financial_crisis_start = pd.to_datetime("2007-10-01")
financial_crisis_end = pd.to_datetime("2009-06-30")
covid_crisis_start = pd.to_datetime("2020-01-01")
covid_crisis_end = pd.to_datetime("2021-12-31")

# Plot the Total Taxes over time with quarterly granularity and adjusted green shading
plt.figure(figsize=(14, 8))

# Plot total taxes as a line graph
plt.plot(quarterly_taxes.index, quarterly_taxes, marker='o', color='black', linewidth=2, label="Total Taxes")

# Highlight economic periods with adjusted green shading
plt.axvspan(financial_crisis_start, financial_crisis_end, color=green_shades[4], alpha=0.4, label="2008 Financial Crisis (Darker)")
plt.axvspan(financial_crisis_end, pd.to_datetime("2019-12-31"), color=green_shades[2], alpha=0.3, label="Post-2008 Recovery")
plt.axvspan(covid_crisis_start, covid_crisis_end, color=green_shades[4], alpha=0.4, label="COVID-19 Crisis (Darker)")
plt.axvspan(covid_crisis_end, quarterly_taxes.index.max(), color=green_shades[2], alpha=0.3, label="Post-COVID Recovery")

# Add titles and labels
plt.title("Total Tax Revenue Trends with Enhanced Shading for Economic and Recovery Periods", fontsize=18, weight='bold')
plt.xlabel("Quarter", fontsize=14)
plt.ylabel("Total Taxes (Billions)", fontsize=14)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=12)
plt.legend(fontsize=12, loc='upper left')
plt.grid(visible=True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 6
#       3 import pandas as pd
#       5 # Updated way to get colormap
# ----> 6 green_cmap = plt.colormaps.get_cmap('Greens', 5)
#       7 green_shades = [mcolors.to_hex(green_cmap(i)) for i in range(5)]
#       9 # Example dataset: Replace with your actual dataset
#      10 # Ensure quarterly_taxes is a pandas Series with a datetime index
#      11 # Example data creation (remove if you already have your data):
#
# TypeError: ColormapRegistry.get_cmap() takes 2 positional arguments but 3 were given

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd
import numpy as np

# Updated way to get a colormap and sample specific shades
green_cmap = plt.colormaps["Greens"]
green_shades = [mcolors.to_hex(green_cmap(i)) for i in np.linspace(0, 1, 5)]

# Example dataset: Replace with your actual dataset
# Ensure quarterly_taxes is a pandas Series with a datetime index
# Example data creation (remove if you already have your data):
data = {
    "Time": pd.date_range(start="2000-01-01", end="2025-01-01", freq="Q"),
    "Total Taxes": [500 + i * 10 for i in range(101)],
}
df = pd.DataFrame(data).set_index("Time")
quarterly_taxes = df["Total Taxes"]

# Define key periods
financial_crisis_start = pd.to_datetime("2007-10-01")
financial_crisis_end = pd.to_datetime("2009-06-30")
covid_crisis_start = pd.to_datetime("2020-01-01")
covid_crisis_end = pd.to_datetime("2021-12-31")

# Plot the Total Taxes over time with quarterly granularity and adjusted green shading
plt.figure(figsize=(14, 8))

# Plot total taxes as a line graph
plt.plot(quarterly_taxes.index, quarterly_taxes, marker='o', color='black', linewidth=2, label="Total Taxes")

# Highlight economic periods with adjusted green shading
plt.axvspan(financial_crisis_start, financial_crisis_end, color=green_shades[4], alpha=0.4, label="2008 Financial Crisis (Darker)")
plt.axvspan(financial_crisis_end, pd.to_datetime("2019-12-31"), color=green_shades[2], alpha=0.3, label="Post-2008 Recovery")
plt.axvspan(covid_crisis_start, covid_crisis_end, color=green_shades[4], alpha=0.4, label="COVID-19 Crisis (Darker)")
plt.axvspan(covid_crisis_end, quarterly_taxes.index.max(), color=green_shades[2], alpha=0.3, label="Post-COVID Recovery")

# Add titles and labels
plt.title("Total Tax Revenue Trends with Enhanced Shading for Economic and Recovery Periods", fontsize=18, weight='bold')
plt.xlabel("Quarter", fontsize=14)
plt.ylabel("Total Taxes (Billions)", fontsize=14)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=12)
plt.legend(fontsize=12, loc='upper left')
plt.grid(visible=True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/_c/wwh4ntjd79zgv89r7tdw_dwc0000gn/T/ipykernel_56717/2256337204.py:14: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   "Time": pd.date_range(start="2000-01-01", end="2025-01-01", freq="Q"),
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[130], line 17
#      10 # Example dataset: Replace with your actual dataset
#      11 # Ensure quarterly_taxes is a pandas Series with a datetime index
#      12 # Example data creation (remove if you already have your data):
#      13 data = {
#      14     "Time": pd.date_range(start="2000-01-01", end="2025-01-01", freq="Q"),
#      15     "Total Taxes": [500 + i * 10 for i in range(101)],
#      16 }
# ---> 17 df = pd.DataFrame(data).set_index("Time")
#      18 quarterly_taxes = df["Total Taxes"]
#      20 # Define key periods
#
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd
import numpy as np

# Updated way to get a colormap and sample specific shades
green_cmap = plt.colormaps["Greens"]
green_shades = [mcolors.to_hex(green_cmap(i)) for i in np.linspace(0, 1, 5)]

# Corrected example dataset
dates = pd.date_range(start="2000-01-01", end="2025-01-01", freq="Q")
total_taxes = [500 + i * 10 for i in range(len(dates))]
df = pd.DataFrame({"Time": dates, "Total Taxes": total_taxes}).set_index("Time")
quarterly_taxes = df["Total Taxes"]

# Define key periods
financial_crisis_start = pd.to_datetime("2007-10-01")
financial_crisis_end = pd.to_datetime("2009-06-30")
covid_crisis_start = pd.to_datetime("2020-01-01")
covid_crisis_end = pd.to_datetime("2021-12-31")

# Plot the Total Taxes over time with quarterly granularity and adjusted green shading
plt.figure(figsize=(14, 8))

# Plot total taxes as a line graph
plt.plot(quarterly_taxes.index, quarterly_taxes, marker='o', color='black', linewidth=2, label="Total Taxes")

# Highlight economic periods with adjusted green shading
plt.axvspan(financial_crisis_start, financial_crisis_end, color=green_shades[4], alpha=0.4, label="2008 Financial Crisis (Darker)")
plt.axvspan(financial_crisis_end, pd.to_datetime("2019-12-31"), color=green_shades[2], alpha=0.3, label="Post-2008 Recovery")
plt.axvspan(covid_crisis_start, covid_crisis_end, color=green_shades[4], alpha=0.4, label="COVID-19 Crisis (Darker)")
plt.axvspan(covid_crisis_end, quarterly_taxes.index.max(), color=green_shades[2], alpha=0.3, label="Post-COVID Recovery")

# Add titles and labels
plt.title("Total Tax Revenue Trends with Enhanced Shading for Economic and Recovery Periods", fontsize=18, weight='bold')
plt.xlabel("Quarter", fontsize=14)
plt.ylabel("Total Taxes (Billions)", fontsize=14)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=12)
plt.legend(fontsize=12, loc='upper left')
plt.grid(visible=True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/_c/wwh4ntjd79zgv89r7tdw_dwc0000gn/T/ipykernel_56717/2913420254.py:11: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   dates = pd.date_range(start="2000-01-01", end="2025-01-01", freq="Q")

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd
import numpy as np

# Updated way to get a colormap and sample specific shades
green_cmap = plt.colormaps["Greens"]
green_shades = [mcolors.to_hex(green_cmap(i)) for i in np.linspace(0, 1, 5)]

# Corrected example dataset
dates = pd.date_range(start="2000-01-01", end="2025-01-01", freq="Q-DEC")
total_taxes = [500 + i * 10 for i in range(len(dates))]
df = pd.DataFrame({"Time": dates, "Total Taxes": total_taxes}).set_index("Time")
quarterly_taxes = df["Total Taxes"]

# Define key periods
financial_crisis_start = pd.to_datetime("2007-10-01")
financial_crisis_end = pd.to_datetime("2009-06-30")
covid_crisis_start = pd.to_datetime("2020-01-01")
covid_crisis_end = pd.to_datetime("2021-12-31")

# Plot the Total Taxes over time with quarterly granularity and adjusted green shading
plt.figure(figsize=(14, 8))

# Plot total taxes as a line graph
plt.plot(quarterly_taxes.index, quarterly_taxes, marker='o', color='black', linewidth=2, label="Total Taxes")

# Highlight economic periods with adjusted green shading
plt.axvspan(financial_crisis_start, financial_crisis_end, color=green_shades[4], alpha=0.4, label="2008 Financial Crisis (Darker)")
plt.axvspan(financial_crisis_end, pd.to_datetime("2019-12-31"), color=green_shades[2], alpha=0.3, label="Post-2008 Recovery")
plt.axvspan(covid_crisis_start, covid_crisis_end, color=green_shades[4], alpha=0.4, label="COVID-19 Crisis (Darker)")
plt.axvspan(covid_crisis_end, quarterly_taxes.index.max(), color=green_shades[2], alpha=0.3, label="Post-COVID Recovery")

# Add titles and labels
plt.title("Total Tax Revenue Trends with Enhanced Shading for Economic and Recovery Periods", fontsize=18, weight='bold')
plt.xlabel("Quarter", fontsize=14)
plt.ylabel("Total Taxes (Billions)", fontsize=14)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=12)
plt.legend(fontsize=12, loc='upper left')
plt.grid(visible=True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/_c/wwh4ntjd79zgv89r7tdw_dwc0000gn/T/ipykernel_56717/1850828026.py:11: FutureWarning: 'Q-DEC' is deprecated and will be removed in a future version, please use 'QE-DEC' instead.
#   dates = pd.date_range(start="2000-01-01", end="2025-01-01", freq="Q-DEC")

# %%
# Define a green color gradient for shading with darker crisis colors
green_cmap = cm.get_cmap('Greens', 5)
green_shades = [mcolors.to_hex(green_cmap(i)) for i in range(5)]

# Plot the Total Taxes over time with quarterly granularity and adjusted green shading
plt.figure(figsize=(14, 8))

# Plot total taxes as a line graph
plt.plot(quarterly_taxes.index, quarterly_taxes, marker='o', color='black', linewidth=2, label="Total Taxes")

# Highlight economic periods with adjusted green shading
plt.axvspan(financial_crisis_start, financial_crisis_end, color=green_shades[4], alpha=0.4, label="2008 Financial Crisis (Darker)")
plt.axvspan(financial_crisis_end, pd.to_datetime("2019-12-31"), color=green_shades[2], alpha=0.3, label="Post-2008 Recovery")
plt.axvspan(covid_crisis_start, covid_crisis_end, color=green_shades[4], alpha=0.4, label="COVID-19 Crisis (Darker)")
plt.axvspan(covid_crisis_end, quarterly_taxes.index.max(), color=green_shades[2], alpha=0.3, label="Post-COVID Recovery")

# Add titles and labels
plt.title("Total Tax Revenue Trends with Enhanced Shading for Economic and Recovery Periods", fontsize=18, weight='bold')
plt.xlabel("Quarter", fontsize=14)
plt.ylabel("Total Taxes (Billions)", fontsize=14)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=12)
plt.legend(fontsize=12, loc='upper left')
plt.grid(visible=True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/_c/wwh4ntjd79zgv89r7tdw_dwc0000gn/T/ipykernel_56717/3925258013.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   green_cmap = cm.get_cmap('Greens', 5)

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd
import numpy as np

# Generate example dataset: Quarterly data
dates = pd.date_range(start="2000-01-01", end="2025-01-01", freq="QS")
total_taxes = [500 + i * 10 for i in range(len(dates))]
df = pd.DataFrame({"Time": dates, "Total Taxes": total_taxes}).set_index("Time")
quarterly_taxes = df["Total Taxes"]

# Define key periods
financial_crisis_start = pd.to_datetime("2007-10-01")
financial_crisis_end = pd.to_datetime("2009-06-30")
covid_crisis_start = pd.to_datetime("2020-01-01")
covid_crisis_end = pd.to_datetime("2021-12-31")

# Plot the Total Taxes over time with quarterly granularity
plt.figure(figsize=(14, 8))

# Plot total taxes as a line graph
plt.plot(quarterly_taxes.index, quarterly_taxes, marker='o', color='black', linewidth=2, label="Total Taxes")

# Highlight economic periods with green shading
plt.axvspan(financial_crisis_start, financial_crisis_end, color='darkgreen', alpha=0.3, label="2008 Financial Crisis")
plt.axvspan(financial_crisis_end, pd.to_datetime("2019-12-31"), color='lightgreen', alpha=0.3, label="Post-2008 Recovery")
plt.axvspan(covid_crisis_start, covid_crisis_end, color='darkgreen', alpha=0.3, label="COVID-19 Crisis")
plt.axvspan(covid_crisis_end, quarterly_taxes.index.max(), color='lightgreen', alpha=0.3, label="Post-COVID Recovery")

# Add titles and labels
plt.title("Total Tax Revenue Trends with Quarterly Shading for Economic Periods", fontsize=18, weight='bold')
plt.xlabel("Quarter", fontsize=14)
plt.ylabel("Total Taxes (Billions)", fontsize=14)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=12)
plt.legend(fontsize=12, loc='upper left')
plt.grid(visible=True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
# Map quarters to starting months
quarter_to_month = {"Q1": "01", "Q2": "04", "Q3": "07", "Q4": "10"}

# Construct a valid datetime column
cleaned_data["Date"] = pd.to_datetime(
    cleaned_data["Year"].astype(str) + "-" + cleaned_data["Quarter"].map(quarter_to_month)
)

# Set the Date column as the index
cleaned_data.set_index("Date", inplace=True)

# Calculate Total Taxes if not already done
cleaned_data["Total Taxes"] = (
    cleaned_data["Personal current taxes"].astype(float)
    + cleaned_data["Taxes on production and imports"].astype(float)
    + cleaned_data["Taxes on corporate income"].astype(float)
)

# Extract Total Taxes as a time series
quarterly_taxes = cleaned_data["Total Taxes"]

# Display the cleaned and processed data
quarterly_taxes.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[140], line 6
#       2 quarter_to_month = {"Q1": "01", "Q2": "04", "Q3": "07", "Q4": "10"}
#       4 # Construct a valid datetime column
#       5 cleaned_data["Date"] = pd.to_datetime(
# ----> 6     cleaned_data["Year"].astype(str) + "-" + cleaned_data["Quarter"].map(quarter_to_month)
#       7 )
#       9 # Set the Date column as the index
#      10 cleaned_data.set_index("Date", inplace=True)
#
# NameError: name 'cleaned_data' is not defined

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the cleaned dataset
file_path = "Cleaned_Fiscal.csv"  # Replace with your file path if different
data = pd.read_csv(file_path, parse_dates=["Date"], index_col="Date")

# Extract Total Taxes time series
quarterly_taxes = data["Total Taxes"]

# Define key periods for crises and recovery
financial_crisis_start = pd.to_datetime("2007-10-01")
financial_crisis_end = pd.to_datetime("2009-06-30")
covid_crisis_start = pd.to_datetime("2020-01-01")
covid_crisis_end = pd.to_datetime("2021-12-31")

# Plot the Total Taxes over time with quarterly granularity
plt.figure(figsize=(14, 8))

# Plot total taxes as a line graph
plt.plot(quarterly_taxes.index, quarterly_taxes, marker='o', color='black', linewidth=2, label="Total Taxes")

# Highlight economic periods with green shading
plt.axvspan(financial_crisis_start, financial_crisis_end, color='darkgreen', alpha=0.3, label="2008 Financial Crisis")
plt.axvspan(financial_crisis_end, pd.to_datetime("2019-12-31"), color='lightgreen', alpha=0.3, label="Post-2008 Recovery")
plt.axvspan(covid_crisis_start, covid_crisis_end, color='darkgreen', alpha=0.3, label="COVID-19 Crisis")
plt.axvspan(covid_crisis_end, quarterly_taxes.index.max(), color='lightgreen', alpha=0.3, label="Post-COVID Recovery")

# Add titles and labels
plt.title("Total Tax Revenue Trends with Quarterly Shading for Economic Periods", fontsize=18, weight='bold')
plt.xlabel("Quarter", fontsize=14)
plt.ylabel("Total Taxes (Billions)", fontsize=14)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=12)
plt.legend(fontsize=12, loc='upper left')
plt.grid(visible=True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
